# %% [markdown]
# <a href="https://colab.research.google.com/github/nat5natalia/spaceship_titanic/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set() # устанавливаем seaborn как по-умолчанию для отрисовки графиков

# %%
# Подключение Google Диска
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train = pd.read_csv('/content/drive/MyDrive/train.csv')
test = pd.read_csv('/content/drive/MyDrive/test.csv')

# %% [markdown]
# # Train structure

# %%
train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
train.shape
# Out:
# (891, 12)

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train.describe(include=['O'])
# Out:
#                        Name   Sex  Ticket Cabin Embarked
# count                   891   891     891   204      889
# unique                  891     2     681   147        3
# top     Dooley, Mr. Patrick  male  347082    G6        S
# freq                      1   577       7     4      644

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # Test structure

# %%
test.shape
# Out:
# (418, 11)

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.1+ KB

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
survived = train[train['Survived'] == 1]
not_survived = train[train['Survived'] == 0]

print ("Survived: %i (%.1f%%)"%(len(survived), (len(survived))/len(train)*100.0))
print ("Not Survived: %i (%.1f%%)"%(len(not_survived), (len(not_survived))/len(train)*100.0))
print ("Total: %i"%len(train))
# Out:
# Survived: 342 (38.4%)
# Not Survived: 549 (61.6%)
# Total: 891

# %% [markdown]
# # Pclass vs. Survival

# %%
train.Pclass.value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
train.groupby('Pclass').Survived.value_counts()
# Out:
# Pclass  Survived
# 1       1           136
#         0            80
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: count, dtype: int64

# %%
train[['Pclass', 'Survived']].groupby('Pclass', as_index = False).mean()
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %%
sns.barplot(x='Pclass', y='Survived', data=train, errorbar=None) # ci=None -> turns off confidence intervals
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %% [markdown]
# # Sex vs. Survival

# %%
train.Sex.value_counts()
train.groupby('Sex').Survived.value_counts()
# Out:
# Sex     Survived
# female  1           233
#         0            81
# male    0           468
#         1           109
# Name: count, dtype: int64

# %%
train[['Sex', 'Survived']].groupby(['Sex'], as_index=False).mean()
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
sns.barplot(x='Sex', y='Survived', data=train, ci=None)
# Out:
# /tmp/ipython-input-645829002.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Sex', y='Survived', data=train, ci=None)
# <Axes: xlabel='Sex', ylabel='Survived'>

# %% [markdown]
# # Pclass & Sex vs. Survival

# %%
tab = pd.crosstab(train['Pclass'], train['Sex'])
print (tab)
# Out:
# Sex     female  male
# Pclass
# 1           94   122
# 2           76   108
# 3          144   347

# %%
tab = pd.crosstab(train['Pclass'], train['Sex'])
print (tab)

tab.div(tab.sum(1).astype(float), axis=0).plot(kind="bar", stacked=False)
plt.xlabel('Pclass')
plt.ylabel('Percentage')
# Out:
# Sex     female  male
# Pclass
# 1           94   122
# 2           76   108
# 3          144   347
# Text(0, 0.5, 'Percentage')

# %%
sns.catplot(x='Pclass', y='Survived', hue='Sex', aspect=2, data=train, kind='point', errorbar=None)

# %% [markdown]
# # Embarked vs. Survival

# %%
train.Embarked.value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
train.groupby('Embarked').Survived.value_counts()
train[['Survived', 'Embarked']].groupby(['Embarked'], as_index = True).mean()
# Out:
#           Survived
# Embarked
# C         0.553571
# Q         0.389610
# S         0.336957

# %%
tab = pd.crosstab(train['Embarked'], train['Survived'])
print (tab)
tab.div(tab.sum(1).astype(float), axis=0).plot(kind='bar', stacked=False)
plt.xlabel('Embarked')
plt.ylabel('Percentage')
# Out:
# Survived    0    1
# Embarked
# C          75   93
# Q          47   30
# S         427  217
# Text(0, 0.5, 'Percentage')

# %%
sns.catplot(x='Embarked', y='Survived', data=train, kind='bar', errorbar=None)

# %% [markdown]
# # Pclass vs. Embarked vs. Survival

# %%
sns.catplot(x='Embarked', y='Survived', hue='Pclass', aspect=2, data=train, kind='bar', errorbar=None)

# %%
tab = pd.crosstab(train['Embarked'], train['Pclass'])
print (tab)
# Out:
# Pclass      1    2    3
# Embarked
# C          85   17   66
# Q           2    3   72
# S         127  164  353

# %%
tab.div(tab.sum(1).astype(float), axis=0).plot(kind="bar", stacked=False)
plt.xlabel('Embarked')
plt.ylabel('Percentage')
# Out:
# Text(0, 0.5, 'Percentage')

# %%
total_survived = train[train['Survived']==1]
total_not_survived = train[train['Survived']==0]
male_survived = train[(train['Survived']==1) & (train['Sex']=="male")]
#male_survived = total_survived[total_survived['Sex']=='male']
female_survived = train[(train['Survived']==1) & (train['Sex']=="female")]
male_not_survived = train[(train['Survived']==0) & (train['Sex']=="male")]
female_not_survived = train[(train['Survived']==0) & (train['Sex']=="female")]

fig = plt.figure(figsize=[15,10])
ax1 = fig.add_subplot(211)
sns.histplot(total_survived['Age'].dropna().values, bins=range(0, 81, 1), kde=False, color='blue', ax=ax1, label='Survived')
sns.histplot(total_not_survived['Age'].dropna().values, bins=range(0, 81, 1), kde=False, color='red', ax=ax1, label='Not Survived')
ax1.set_xlabel('Age')
ax1.set_ylabel('Count')
ax1.legend()
ax1.set_title('Age Distribution - Total')

ax2 = fig.add_subplot(223)
sns.histplot(female_survived['Age'].dropna().values, bins=range(0, 81, 1), kde=False, color='blue', ax=ax2, label='Survived')
sns.histplot(female_not_survived['Age'].dropna().values, bins=range(0, 81, 1), kde=False, color='red', ax=ax2, label='Not Survived')
ax2.set_xlabel('Female Age')
ax2.set_ylabel('Count')
ax2.legend()
ax2.set_title('Age Distribution - Female')

ax3 = fig.add_subplot(224)
sns.histplot(male_survived['Age'].dropna().values, bins=range(0, 81, 1), kde=False, color='blue', ax=ax3, label='Survived')
sns.histplot(male_not_survived['Age'].dropna().values, bins=range(0, 81, 1), kde=False, color='red', ax=ax3, label='Not Survived')
ax3.set_xlabel('Male Age')
ax3.set_ylabel('Count')
ax3.legend()
ax3.set_title('Age Distribution - Male')
# Out:
# Text(0.5, 1.0, 'Age Distribution - Male')

# %%
fig = plt.figure(figsize=(12,4))
ax1 = fig.add_subplot(131)
ax2 = fig.add_subplot(132)
ax3 = fig.add_subplot(133)


sns.violinplot(x="Embarked", y="Age", hue="Survived", data=train, split=True, ax=ax1)
sns.violinplot(x="Pclass", y="Age", hue="Survived", data=train, split=True, ax=ax2)
sns.violinplot(x="Sex", y="Age", hue="Survived", data=train, split=True, ax=ax3)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %% [markdown]
# # Parch vs. Survival

# %%
train.Parch.value_counts()
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %%
train.groupby('Parch').Survived.value_counts()
# Out:
# Parch  Survived
# 0      0           445
#        1           233
# 1      1            65
#        0            53
# 2      0            40
#        1            40
# 3      1             3
#        0             2
# 4      0             4
# 5      0             4
#        1             1
# 6      0             1
# Name: count, dtype: int64

# %%
train[['Survived', 'Parch']].groupby(['Parch'], as_index = True).mean()
# Out:
#        Survived
# Parch
# 0      0.343658
# 1      0.550847
# 2      0.500000
# 3      0.600000
# 4      0.000000
# 5      0.200000
# 6      0.000000

# %%
tab = pd.crosstab(train['Parch'], train['Survived'])
print (tab)
tab.div(tab.sum(1).astype(float), axis=0).plot(kind='bar', stacked=False)
plt.xlabel('Parch')
plt.ylabel('Percentage')
# Out:
# Survived    0    1
# Parch
# 0         445  233
# 1          53   65
# 2          40   40
# 3           2    3
# 4           4    0
# 5           4    1
# 6           1    0
# Text(0, 0.5, 'Percentage')

# %%
sns.catplot(x='Parch', y='Survived', data=train, kind='bar', errorbar=None)

# %% [markdown]
# # SibSp vs. Survival

# %%
train['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
train.groupby('SibSp').Survived.value_counts()
# Out:
# SibSp  Survived
# 0      0           398
#        1           210
# 1      1           112
#        0            97
# 2      0            15
#        1            13
# 3      0            12
#        1             4
# 4      0            15
#        1             3
# 5      0             5
# 8      0             7
# Name: count, dtype: int64

# %%
train[['Survived', 'SibSp']].groupby(['SibSp'], as_index = True).mean()
# Out:
#        Survived
# SibSp
# 0      0.345395
# 1      0.535885
# 2      0.464286
# 3      0.250000
# 4      0.166667
# 5      0.000000
# 8      0.000000

# %%
tab = pd.crosstab(train['SibSp'], train['Survived'])
print (tab)
tab.div(tab.sum(1).astype(float), axis=0).plot(kind='bar', stacked=False)
plt.xlabel('SibSp')
plt.ylabel('Percentage')
# Out:
# Survived    0    1
# SibSp
# 0         398  210
# 1          97  112
# 2          15   13
# 3          12    4
# 4          15    3
# 5           5    0
# 8           7    0
# Text(0, 0.5, 'Percentage')

# %%
sns.catplot(x='SibSp', y='Survived', data=train, kind='bar', errorbar=None)

# %% [markdown]
# # Age vs. Survival

# %%
train['Age'].value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 30.00    25
#          ..
# 24.50     1
# 0.67      1
# 0.42      1
# 34.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %% [markdown]
# # Correlation

# %%
numer = train.select_dtypes(include=['number']).columns
corr_matrix = train[numer].corr()
corr_matrix
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
plt.figure(figsize=(15,6))
sns.heatmap(corr_matrix, vmax=0.6, square=True, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Feature Extraction

# %%
train_test_data = [train, test] # combining train and test dataset

for dataset in train_test_data:
    dataset['Title'] = dataset.Name.str.extract(r' ([A-Za-z]+)\.')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Title
# 0      0         A/5 21171   7.2500   NaN        S    Mr
# 1      0          PC 17599  71.2833   C85        C   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Miss
# 3      0            113803  53.1000  C123        S   Mrs
# ...

# %%
pd.crosstab(train['Title'], train['Sex'])
# Out:
# Sex       female  male
# Title
# Capt           0     1
# Col            0     2
# Countess       1     0
# Don            0     1
# Dr             1     6
# Jonkheer       0     1
# Lady           1     0
# Major          0     2
# Master         0    40
# Miss         182     0
# Mlle           2     0
# Mme            1     0
# Mr             0   517
# Mrs          125     0
# Ms             1     0
# Rev            0     6
# Sir            0     1

# %%
for dataset in train_test_data:
    dataset['Title'] = dataset['Title'].replace(['Lady', 'Countess','Capt', 'Col', \
 	'Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Other')

    dataset['Title'] = dataset['Title'].replace('Mlle', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Ms', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Mme', 'Mrs')

train[['Title', 'Survived']].groupby(['Title'], as_index=False).mean()
# Out:
#     Title  Survived
# 0  Master  0.575000
# 1    Miss  0.702703
# 2      Mr  0.156673
# 3     Mrs  0.793651
# 4   Other  0.347826

# %%
title_mapping = {"Mr": 1, "Master": 2, "Mrs": 3, "Miss": 4, "Other": 5}
for dataset in train_test_data:
    dataset['Title'] = dataset['Title'].map(title_mapping)
    dataset['Title'] = dataset['Title'].fillna(5)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Title
# 0      0         A/5 21171   7.2500   NaN        S    5.0
# 1      0          PC 17599  71.2833   C85        C    5.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S    5.0
# 3      0            113803  53.1000  C123        S    5.0
# ...

# %%
sex_mapping = {'female': 0, 'male': 1}
for dataset in train_test_data:
    dataset['Sex'] = dataset['Sex'].map(sex_mapping)
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Title
# 0         A/5 21171   7.2500   NaN        S    5.0
# 1          PC 17599  71.2833   C85        C    5.0
# 2  STON/O2. 3101282   7.9250   NaN        S    5.0
# 3            113803  53.1000  C123        S    5.0
# ...

# %%
train.Embarked.unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
train.Embarked.value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
for dataset in train_test_data:
    dataset['Embarked'] = dataset['Embarked'].fillna('S')
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Title
# 0         A/5 21171   7.2500   NaN        S    5.0
# 1          PC 17599  71.2833   C85        C    5.0
# 2  STON/O2. 3101282   7.9250   NaN        S    5.0
# 3            113803  53.1000  C123        S    5.0
# ...

# %%
for dataset in train_test_data:
    #print(dataset.Embarked.unique())
    dataset['Embarked'] = dataset['Embarked'].map( {'S': 0, 'C': 1, 'Q': 2} ).astype(int)
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin  Embarked  Title
# 0         A/5 21171   7.2500   NaN         0    5.0
# 1          PC 17599  71.2833   C85         1    5.0
# 2  STON/O2. 3101282   7.9250   NaN         0    5.0
# 3            113803  53.1000  C123         0    5.0
# ...

# %%
for dataset in train_test_data:
    # Заполнение пропущенных значений возраста
    age_avg = dataset['Age'].mean()
    age_std = dataset['Age'].std()
    age_null_count = dataset['Age'].isnull().sum()

    # Генерируем случайные значения для заполнения пропусков
    age_null_random_list = np.random.randint(age_avg - age_std, age_avg + age_std, size=age_null_count)

    dataset.loc[dataset['Age'].isnull(), 'Age'] = age_null_random_list
    dataset['Age'] = dataset['Age'].astype(int)

for dataset in train_test_data:
    dataset['AgeBand'] = pd.cut(train['Age'], 5)

print (train[['AgeBand', 'Survived']].groupby(['AgeBand'], observed=True, as_index=False).mean())
# Out:
#          AgeBand  Survived
# 0  (-0.08, 16.0]  0.495652
# 1   (16.0, 32.0]  0.371298
# 2   (32.0, 48.0]  0.354086
# 3   (48.0, 64.0]  0.434783
# 4   (64.0, 80.0]  0.090909

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex  Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1   22      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0   38      1      0
# 2                             Heikkinen, Miss. Laina    0   26      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0   35      1      0
# 4                           Allen, Mr. William Henry    1   35      0      0
#
#              Ticket     Fare Cabin  Embarked  Title       AgeBand
# 0         A/5 21171   7.2500   NaN         0    5.0  (16.0, 32.0]
# 1          PC 17599  71.2833   C85         1    5.0  (32.0, 48.0]
# 2  STON/O2. 3101282   7.9250   NaN         0    5.0  (16.0, 32.0]
# ...

# %%
for dataset in train_test_data:
    dataset.loc[ dataset['Age'] <= 16, 'Age'] = 0
    dataset.loc[(dataset['Age'] > 16) & (dataset['Age'] <= 32), 'Age'] = 1
    dataset.loc[(dataset['Age'] > 32) & (dataset['Age'] <= 48), 'Age'] = 2
    dataset.loc[(dataset['Age'] > 48) & (dataset['Age'] <= 64), 'Age'] = 3
    dataset.loc[ dataset['Age'] > 64, 'Age'] = 4

train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex  Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1    1      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0    2      1      0
# 2                             Heikkinen, Miss. Laina    0    1      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0    2      1      0
# 4                           Allen, Mr. William Henry    1    2      0      0
#
#              Ticket     Fare Cabin  Embarked  Title       AgeBand
# 0         A/5 21171   7.2500   NaN         0    5.0  (16.0, 32.0]
# 1          PC 17599  71.2833   C85         1    5.0  (32.0, 48.0]
# 2  STON/O2. 3101282   7.9250   NaN         0    5.0  (16.0, 32.0]
# ...

# %%
for dataset in train_test_data:
    dataset['Fare'] = dataset['Fare'].fillna(train['Fare'].median())

# %%
for dataset in train_test_data:
    dataset['FareBand'] = pd.qcut(train['Fare'], 4)

print (train[['FareBand', 'Survived']].groupby(['FareBand'], as_index=False, observed=True).mean())
# Out:
#           FareBand  Survived
# 0   (-0.001, 7.91]  0.197309
# 1   (7.91, 14.454]  0.303571
# 2   (14.454, 31.0]  0.454955
# 3  (31.0, 512.329]  0.581081

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex  Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1    1      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0    2      1      0
# 2                             Heikkinen, Miss. Laina    0    1      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0    2      1      0
# 4                           Allen, Mr. William Henry    1    2      0      0
#
#              Ticket     Fare Cabin  Embarked  Title       AgeBand  \
# 0         A/5 21171   7.2500   NaN         0    5.0  (16.0, 32.0]
# 1          PC 17599  71.2833   C85         1    5.0  (32.0, 48.0]
# 2  STON/O2. 3101282   7.9250   NaN         0    5.0  (16.0, 32.0]
# ...

# %%
for dataset in train_test_data:
    dataset.loc[ dataset['Fare'] <= 7.91, 'Fare'] = 0
    dataset.loc[(dataset['Fare'] > 7.91) & (dataset['Fare'] <= 14.454), 'Fare'] = 1
    dataset.loc[(dataset['Fare'] > 14.454) & (dataset['Fare'] <= 31), 'Fare']   = 2
    dataset.loc[ dataset['Fare'] > 31, 'Fare'] = 3
    dataset['Fare'] = dataset['Fare'].astype(int)

train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex  Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1    1      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0    2      1      0
# 2                             Heikkinen, Miss. Laina    0    1      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0    2      1      0
# 4                           Allen, Mr. William Henry    1    2      0      0
#
#              Ticket  Fare Cabin  Embarked  Title       AgeBand  \
# 0         A/5 21171     0   NaN         0    5.0  (16.0, 32.0]
# 1          PC 17599     3   C85         1    5.0  (32.0, 48.0]
# 2  STON/O2. 3101282     1   NaN         0    5.0  (16.0, 32.0]
# ...

# %%
for dataset in train_test_data:
    dataset['FamilySize'] = dataset['SibSp'] +  dataset['Parch'] + 1
print (train[['FamilySize', 'Survived']].groupby(['FamilySize'], as_index=False).mean())
# Out:
#    FamilySize  Survived
# 0           1  0.303538
# 1           2  0.552795
# 2           3  0.578431
# 3           4  0.724138
# 4           5  0.200000
# 5           6  0.136364
# 6           7  0.333333
# 7           8  0.000000
# 8          11  0.000000

# %%
for dataset in train_test_data:
    dataset['IsAlone'] = 0
    dataset.loc[dataset['FamilySize'] == 1, 'IsAlone'] = 1

print (train[['IsAlone', 'Survived']].groupby(['IsAlone'], as_index=False).mean())
# Out:
#    IsAlone  Survived
# 0        0  0.505650
# 1        1  0.303538

# %%
train.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name  Sex  Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris    1    1      1
#
#    Parch     Ticket  Fare Cabin  Embarked  Title       AgeBand  \
# 0      0  A/5 21171     0   NaN         0    5.0  (16.0, 32.0]
#
#          FareBand  FamilySize  IsAlone
# 0  (-0.001, 7.91]           2        0

# %% [markdown]
# # Feature selection

# %%
features_drop = ['Name', 'SibSp', 'Parch', 'Ticket', 'Cabin', 'FareBand', 'AgeBand']
train = train.drop(features_drop, axis=1)
test = test.drop(features_drop, axis=1)
train = train.drop(['PassengerId'], axis=1)

# %%
train.head()
# Out:
#    Survived  Pclass  Sex  Age  Fare  Embarked  Title  FamilySize  IsAlone
# 0         0       3    1    1     0         0    5.0           2        0
# 1         1       1    0    2     3         1    5.0           2        0
# 2         1       3    0    1     1         0    5.0           1        1
# 3         1       1    0    2     3         0    5.0           2        0
# 4         0       3    1    2     1         0    5.0           1        1

# %%
test.head()
# Out:
#    PassengerId  Pclass  Sex  Age  Fare  Embarked  Title  FamilySize  IsAlone
# 0          892       3    1    2     0         2    5.0           1        1
# 1          893       3    0    2     0         0    5.0           2        0
# 2          894       2    1    3     1         2    5.0           1        1
# 3          895       3    1    1     1         0    5.0           1        1
# 4          896       3    0    1     1         0    5.0           3        0

# %%
plt.figure(figsize=(15,6))
sns.heatmap(train.corr(), vmax=0.6, square=True, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Classifier

# %%
X_train = train.drop('Survived', axis=1)
y_train = train['Survived']

X_test = test.drop("PassengerId", axis=1).copy()

X_train.shape, y_train.shape, X_test.shape
# Out:
# ((891, 8), (891,), (418, 8))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier

# %% [markdown]
# # Logistic regression

# %%
clf = LogisticRegression()
clf.fit(X_train, y_train)
y_pred_log_reg = clf.predict(X_test)
acc_log_reg = round( clf.score(X_train, y_train) * 100, 2)
print (str(acc_log_reg) + ' percent')
# Out:
# 80.25 percent

# %% [markdown]
# # Support Vector Machine (SVM)

# %%
clf = SVC()
clf.fit(X_train, y_train)
y_pred_svc = clf.predict(X_test)
acc_svc = round(clf.score(X_train, y_train) * 100, 2)
print (acc_svc)
# Out:
# 81.03

# %% [markdown]
# # LinearSVC

# %%
clf = LinearSVC()
clf.fit(X_train, y_train)
y_pred_linear_svc = clf.predict(X_test)
acc_linear_svc = round(clf.score(X_train, y_train) * 100, 2)
print (acc_linear_svc)
# Out:
# 79.8

# %% [markdown]
# # KNeighborsClassifier

# %%
clf = KNeighborsClassifier(n_neighbors = 3)
clf.fit(X_train, y_train)
y_pred_knn = clf.predict(X_test)
acc_knn = round(clf.score(X_train, y_train) * 100, 2)
print (acc_knn)
# Out:
# 84.29

# %% [markdown]
# # Decision tree

# %%
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)
y_pred_decision_tree = clf.predict(X_test)
acc_decision_tree = round(clf.score(X_train, y_train) * 100, 2)
print (acc_decision_tree)
# Out:
# 87.65

# %% [markdown]
# # Random forest

# %%
clf = RandomForestClassifier(n_estimators=100)
clf.fit(X_train, y_train)
y_pred_random_forest = clf.predict(X_test)
acc_random_forest = round(clf.score(X_train, y_train) * 100, 2)
print (acc_random_forest)
# Out:
# 87.65

# %% [markdown]
# # Gaussian Naive Bayes

# %%
clf = GaussianNB()
clf.fit(X_train, y_train)
y_pred_gnb = clf.predict(X_test)
acc_gnb = round(clf.score(X_train, y_train) * 100, 2)
print (acc_gnb)
# Out:
# 77.55

# %% [markdown]
# # Perceptron

# %%
clf = Perceptron(max_iter=5, tol=None)
clf.fit(X_train, y_train)
y_pred_perceptron = clf.predict(X_test)
acc_perceptron = round(clf.score(X_train, y_train) * 100, 2)
print (acc_perceptron)
# Out:
# 72.5

# %% [markdown]
# # Стохастический градиентный спуск (SGD)

# %%
clf = SGDClassifier(max_iter=5, tol=None)
clf.fit(X_train, y_train)
y_pred_sgd = clf.predict(X_test)
acc_sgd = round(clf.score(X_train, y_train) * 100, 2)
print (acc_sgd)
# Out:
# 66.44

# %% [markdown]
# # Confusion matrix

# %%
from sklearn.metrics import confusion_matrix
import itertools

clf = RandomForestClassifier(n_estimators=100)
clf.fit(X_train, y_train)
y_pred_random_forest_training_set = clf.predict(X_train)
acc_random_forest = round(clf.score(X_train, y_train) * 100, 2)
print ("Accuracy: %i %% \n"%acc_random_forest)

class_names = ['Survived', 'Not Survived']

# Compute confusion matrix
cnf_matrix = confusion_matrix(y_train, y_pred_random_forest_training_set)

cnf_matrix_percent = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]

true_class_names = ['True Survived', 'True Not Survived']
predicted_class_names = ['Predicted Survived', 'Predicted Not Survived']

df_cnf_matrix = pd.DataFrame(cnf_matrix,
                             index = true_class_names,
                             columns = predicted_class_names)

df_cnf_matrix_percent = pd.DataFrame(cnf_matrix_percent,
                                     index = true_class_names,
                                     columns = predicted_class_names)

plt.figure(figsize = (15,5))

plt.subplot(121)
sns.heatmap(df_cnf_matrix, annot=True, fmt='d')

plt.subplot(122)
sns.heatmap(df_cnf_matrix_percent, annot=True)
# Out:
# Accuracy: 87 %
# <Axes: >

# %%
clf = Perceptron(max_iter=5, tol=None)
clf.fit(X_train, y_train)
y_pred_perceptron = clf.predict(X_train)

acc_perceptron = round(clf.score(X_train, y_train) * 100, 2)
print ("Accuracy: %i %% \n"%acc_perceptron)

#class_names = ['Survived', 'Not Survived']

# Compute confusion matrix
cnf_matrix = confusion_matrix(y_train, y_pred_perceptron)
cnf_matrix_percent = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]

#true_class_names = ['True Survived', 'True Not Survived']
#predicted_class_names = ['Predicted Survived', 'Predicted Not Survived']
df_cnf_matrix = pd.DataFrame(cnf_matrix,
                             index = true_class_names,
                             columns = predicted_class_names)

df_cnf_matrix_percent = pd.DataFrame(cnf_matrix_percent,
                                     index = true_class_names,
                                     columns = predicted_class_names)

plt.figure(figsize = (15,5))

ax1 = plt.subplot(121)
sns.heatmap(df_cnf_matrix, annot=True, fmt='d')
ax1.title.set_text('Perceptron: values')

ax2 = plt.subplot(122)
sns.heatmap(df_cnf_matrix_percent, annot=True)
ax2.title.set_text('Perceptron: %')
# Out:
# Accuracy: 72 %

# %%
models = pd.DataFrame({
    'Model': ['Logistic Regression', 'Support Vector Machines', 'Linear SVC',
              'KNN', 'Decision Tree', 'Random Forest', 'Naive Bayes',
              'Perceptron', 'Stochastic Gradient Decent'],

    'Score': [acc_log_reg, acc_svc, acc_linear_svc,
              acc_knn,  acc_decision_tree, acc_random_forest, acc_gnb,
              acc_perceptron, acc_sgd]
    })

models.sort_values(by='Score', ascending=False)
# Out:
#                         Model  Score
# 4               Decision Tree  87.65
# 5               Random Forest  87.65
# 3                         KNN  84.29
# 1     Support Vector Machines  81.03
# 0         Logistic Regression  80.25
# 2                  Linear SVC  79.80
# 6                 Naive Bayes  77.55
# 7                  Perceptron  72.50
# 8  Stochastic Gradient Decent  66.44

# %% [markdown]
# # Голосование большинством

# %%
from sklearn.ensemble import VotingClassifier

# 1. Dыбираем модели, включенные в голосование
model1 = Perceptron(max_iter=5, tol=None)
model2 = SGDClassifier(max_iter=5, tol=None)
model3 = GaussianNB()

# 2. Сам "голосующий" классификатор
model = VotingClassifier(estimators=[('perceptron', model1), ('sdg', model2), ('nb', model3)], voting='hard')
model.fit(X_train,y_train)

# 3. Confusion Matrix
y_pred_voter = model.predict(X_train)
acc_voter = round(model.score(X_train, y_train) * 100, 2)
print ("Accuracy: %i %% \n"%acc_voter)

#class_names = ['Survived', 'Not Survived']
# Compute confusion matrix
cnf_matrix = confusion_matrix(y_train, y_pred_voter)
cnf_matrix_percent = cnf_matrix.astype('float') / cnf_matrix.sum(axis=1)[:, np.newaxis]

#true_class_names = ['True Survived', 'True Not Survived']
#predicted_class_names = ['Predicted Survived', 'Predicted Not Survived']

df_cnf_matrix = pd.DataFrame(cnf_matrix,
                             index = true_class_names,
                             columns = predicted_class_names)

df_cnf_matrix_percent = pd.DataFrame(cnf_matrix_percent,
                                     index = true_class_names,
                                     columns = predicted_class_names)

plt.figure(figsize = (15,5))

ax1 = plt.subplot(121)
sns.heatmap(df_cnf_matrix, annot=True, fmt='d')
ax1.title.set_text('Voting: values')

ax2 = plt.subplot(122)
sns.heatmap(df_cnf_matrix_percent, annot=True)
ax2.title.set_text('Voting: %')
# Out:
# Accuracy: 78 %

# %% [markdown]
# # Submission

# %%
submission = pd.DataFrame({
        "PassengerId": test["PassengerId"],
        "Survived": y_pred_random_forest
    })

submission.to_csv('submission.csv', index=False)

# %%
from google.colab import files

files.download('submission.csv')
